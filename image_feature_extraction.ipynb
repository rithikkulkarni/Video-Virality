# %% [markdown]
# <a href="https://colab.research.google.com/github/rithikkulkarni/Video-Virality/blob/main/image_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Download thumbnails and extract simple visual features

# %%
# Step 1: Load the CSV
import pandas as pd

url = "https://raw.githubusercontent.com/rithikkulkarni/Video-Virality/refs/heads/main/video_details.csv"
df = pd.read_csv(url)
df.head()
# Out:
#             kind                         etag           id  \
# 0  youtube#video  EZIz8pZ8r7Y3Zwf3HpjS-_Qi5EI  UtUKi4HUBNY
# 1  youtube#video  evXKA9D3t5Lb3hzqhZzfCCb7EH0  0PWC69jDOP8
# 2  youtube#video  6XryOqEiZhKZ7X-SB5rpVaUCu2Y  0wIpL0cYujQ
# 3  youtube#video  zPnzLnqadx_g30YMdUaz0tJ_BAI  994ZZm2aX-E
# 4  youtube#video  n5AIwWOI4BTvQhipK7rJRNOvNy4  GkDEInsCcpQ
#
#                  channel_id   snippet.publishedAt         snippet.channelId  \
# 0  UCNEI-oWOivQJ9IMn8GeCrMg  2025-06-08T20:24:01Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 1  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-31T17:19:00Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 2  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-26T20:29:01Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 3  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-19T16:59:00Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 4  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-10T19:35:00Z  UCNEI-oWOivQJ9IMn8GeCrMg
#
#                               snippet.title  \
# 0        Nimue - Juan Arenosa (Piano Cover)
# 1  Cry - Cigarettes after sex (Piano Cover)
# 2                    hometown glory - adele
# 3        Welcome and goodbye - Dream, Ivory
# 4                    Hope - Mirko Dukanovic
#
#                                  snippet.description  \
# 0  🎹The vibrant melody of “Nimue” by Juan Arenosa...
# 1  🎹The vibrant melody of “cry” by cigarettes aft...
# 2  🎹The vibrant melody of “hometown glory” by Ade...
# 3  🎹The vibrant melody of “welcome and goodbye” b...
# 4  🎹The vibrant melody of “Hope” by Mirko Dukanov...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/UtUKi4HUBNY/default.jpg
# 1  https://i.ytimg.com/vi/0PWC69jDOP8/default.jpg
# 2  https://i.ytimg.com/vi/0wIpL0cYujQ/default.jpg
# 3  https://i.ytimg.com/vi/994ZZm2aX-E/default.jpg
# 4  https://i.ytimg.com/vi/GkDEInsCcpQ/default.jpg
#
#    snippet.thumbnails.default.width  ...  snippet.categoryId  \
# 0                               120  ...                  10
# 1                               120  ...                  10
# 2                               120  ...                  10
# 3                               120  ...                  10
# 4                               120  ...                  10
#
#   snippet.liveBroadcastContent  snippet.defaultLanguage  \
# 0                         none                    en-US
# 1                         none                    en-US
# 2                         none                    en-US
# 3                         none                    en-US
# 4                         none                    en-US
#
#                     snippet.localized.title  \
# 0        Nimue - Juan Arenosa (Piano Cover)
# 1  Cry - Cigarettes after sex (Piano Cover)
# 2                    hometown glory - adele
# 3        Welcome and goodbye - Dream, Ivory
# 4                    Hope - Mirko Dukanovic
#
#                        snippet.localized.description  \
# 0  🎹The vibrant melody of “Nimue” by Juan Arenosa...
# 1  🎹The vibrant melody of “cry” by cigarettes aft...
# 2  🎹The vibrant melody of “hometown glory” by Ade...
# 3  🎹The vibrant melody of “welcome and goodbye” b...
# 4  🎹The vibrant melody of “Hope” by Mirko Dukanov...
#
#    snippet.defaultAudioLanguage  statistics.viewCount statistics.likeCount  \
# 0                         en-US                 10412                784.0
# 1                         en-US                 28792               1414.0
# 2                         en-US                 12000                495.0
# 3                         en-US                 17402                784.0
# 4                         en-US                 18358                714.0
#
#    statistics.favoriteCount  statistics.commentCount
# 0                         0                       73
# 1                         0                      110
# 2                         0                       72
# 3                         0                       92
# 4                         0                      103
#
# [5 rows x 35 columns]

# %%
# Step 2: Extract video IDs
video_ids = df["id"].dropna().unique().tolist()
print(f"Found {len(video_ids)} video IDs.")
# Out:
# Found 168 video IDs.

# %%
# Step 3: Download thumbnails
import os
import requests
from PIL import Image
from io import BytesIO

os.makedirs("thumbnails", exist_ok=True)

def download_thumbnail(video_id):
    url = f"https://i.ytimg.com/vi/{video_id}/mqdefault.jpg"
    path = f"thumbnails/{video_id}.jpg"
    try:
        response = requests.get(url)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img.save(path)
        return path
    except Exception as e:
        print(f"Error downloading {video_id}: {e}")
        return None

paths = [download_thumbnail(vid) for vid in video_ids]

# %%
# Step 4: Extract visual features
import numpy as np

def extract_features(img_path, video_id):
    try:
        img = Image.open(img_path).convert('RGB')
        img_array = np.array(img)

        avg_color = np.mean(img_array, axis=(0, 1))
        brightness = np.mean(img_array)
        contrast = np.std(img_array)

        return {
            "video_id": video_id,
            "avg_red": avg_color[0],
            "avg_green": avg_color[1],
            "avg_blue": avg_color[2],
            "brightness": brightness,
            "contrast": contrast
        }
    except Exception as e:
        print(f"Failed to extract for {video_id}: {e}")
        return None

feature_data = [extract_features(f"thumbnails/{vid}.jpg", vid) for vid in video_ids]
features_df = pd.DataFrame([f for f in feature_data if f is not None])
features_df.head()
# Out:
#       video_id    avg_red  avg_green   avg_blue  brightness   contrast
# 0  UtUKi4HUBNY  34.080816  36.617812  43.345712   38.014780  58.726130
# 1  0PWC69jDOP8  37.773715  31.678142  43.084097   37.511985  63.705403
# 2  0wIpL0cYujQ  29.380017  30.419931  41.579375   33.793108  54.808984
# 3  994ZZm2aX-E  45.244774  23.591406  23.828802   30.888328  49.698068
# 4  GkDEInsCcpQ  29.958542  29.702031  36.463542   32.041372  55.126803

# %%
# Step 5: Merge features_df with original df to created final "merged_df"

# Merge image features with original DataFrame
merged_df = pd.merge(df, features_df, left_on='id', right_on='video_id', how='left')

# Drop the redundant 'video_id' column
merged_df = merged_df.drop('video_id', axis=1)

# Export the merged DataFrame to CSV
merged_df.to_csv("video_data_with_features.csv", index=False)
print("Merged data with image features exported to video_data_with_features.csv")
# Out:
# Merged data with image features exported to video_data_with_features.csv

# %%
merged_df.head()
# Out:
#             kind                         etag           id  \
# 0  youtube#video  EZIz8pZ8r7Y3Zwf3HpjS-_Qi5EI  UtUKi4HUBNY
# 1  youtube#video  evXKA9D3t5Lb3hzqhZzfCCb7EH0  0PWC69jDOP8
# 2  youtube#video  6XryOqEiZhKZ7X-SB5rpVaUCu2Y  0wIpL0cYujQ
# 3  youtube#video  zPnzLnqadx_g30YMdUaz0tJ_BAI  994ZZm2aX-E
# 4  youtube#video  n5AIwWOI4BTvQhipK7rJRNOvNy4  GkDEInsCcpQ
#
#                  channel_id   snippet.publishedAt         snippet.channelId  \
# 0  UCNEI-oWOivQJ9IMn8GeCrMg  2025-06-08T20:24:01Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 1  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-31T17:19:00Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 2  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-26T20:29:01Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 3  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-19T16:59:00Z  UCNEI-oWOivQJ9IMn8GeCrMg
# 4  UCNEI-oWOivQJ9IMn8GeCrMg  2025-05-10T19:35:00Z  UCNEI-oWOivQJ9IMn8GeCrMg
#
#                               snippet.title  \
# 0        Nimue - Juan Arenosa (Piano Cover)
# 1  Cry - Cigarettes after sex (Piano Cover)
# 2                    hometown glory - adele
# 3        Welcome and goodbye - Dream, Ivory
# 4                    Hope - Mirko Dukanovic
#
#                                  snippet.description  \
# 0  🎹The vibrant melody of “Nimue” by Juan Arenosa...
# 1  🎹The vibrant melody of “cry” by cigarettes aft...
# 2  🎹The vibrant melody of “hometown glory” by Ade...
# 3  🎹The vibrant melody of “welcome and goodbye” b...
# 4  🎹The vibrant melody of “Hope” by Mirko Dukanov...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/UtUKi4HUBNY/default.jpg
# 1  https://i.ytimg.com/vi/0PWC69jDOP8/default.jpg
# 2  https://i.ytimg.com/vi/0wIpL0cYujQ/default.jpg
# 3  https://i.ytimg.com/vi/994ZZm2aX-E/default.jpg
# 4  https://i.ytimg.com/vi/GkDEInsCcpQ/default.jpg
#
#    snippet.thumbnails.default.width  ...  snippet.defaultAudioLanguage  \
# 0                               120  ...                         en-US
# 1                               120  ...                         en-US
# 2                               120  ...                         en-US
# 3                               120  ...                         en-US
# 4                               120  ...                         en-US
#
#   statistics.viewCount  statistics.likeCount  statistics.favoriteCount  \
# 0                10412                 784.0                         0
# 1                28792                1414.0                         0
# 2                12000                 495.0                         0
# 3                17402                 784.0                         0
# 4                18358                 714.0                         0
#
#   statistics.commentCount    avg_red  avg_green   avg_blue  brightness  \
# 0                      73  34.080816  36.617812  43.345712   38.014780
# 1                     110  37.773715  31.678142  43.084097   37.511985
# 2                      72  29.380017  30.419931  41.579375   33.793108
# 3                      92  45.244774  23.591406  23.828802   30.888328
# 4                     103  29.958542  29.702031  36.463542   32.041372
#
#     contrast
# 0  58.726130
# 1  63.705403
# 2  54.808984
# 3  49.698068
# 4  55.126803
#
# [5 rows x 40 columns]

# %%
# Step 6: Export features to CSV
merged_df.to_csv("video_details_v2.csv", index=False)
print("Image features exported to image_features.csv")
# Out:
# Image features exported to image_features.csv

# %% [markdown]
# # Step 2: OCR + Text Feature Extraction

# %%
# Install Tesseract OCR engine and text analysis libraries
# !sudo apt-get install tesseract-ocr -y
# !pip install pytesseract textblob
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.2.1)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
import pytesseract
from PIL import Image
from textblob import TextBlob
import os

def extract_text_features(img_path, video_id):
    try:
        img = Image.open(img_path)
        raw_text = pytesseract.image_to_string(img)
        word_count = len(raw_text.strip().split())
        sentiment = TextBlob(raw_text).sentiment.polarity  # -1 to 1

        return {
            "video_id": video_id,
            "thumbnail_text": raw_text.strip(),
            "text_word_count": word_count,
            "text_sentiment": sentiment
        }
    except Exception as e:
        print(f"Error on {video_id}: {e}")
        return None

# Run OCR on all thumbnails from Step 1
ocr_data = [extract_text_features(f"thumbnails/{vid}.jpg", vid) for vid in video_ids]
ocr_df = pd.DataFrame([o for o in ocr_data if o is not None])
ocr_df.head()
# Out:
#       video_id thumbnail_text  text_word_count  text_sentiment
# 0  UtUKi4HUBNY                               0             0.0
# 1  0PWC69jDOP8                               0             0.0
# 2  0wIpL0cYujQ                               0             0.0
# 3  994ZZm2aX-E                               0             0.0
# 4  GkDEInsCcpQ                               0             0.0

# %%
# Merge Step 1 visual features with Step 2 OCR features
combined_df = pd.merge(features_df, ocr_df, on="video_id", how="left")
combined_df.head()
# Out:
#       video_id    avg_red  avg_green   avg_blue  brightness   contrast  \
# 0  UtUKi4HUBNY  34.080816  36.617812  43.345712   38.014780  58.726130
# 1  0PWC69jDOP8  37.773715  31.678142  43.084097   37.511985  63.705403
# 2  0wIpL0cYujQ  29.380017  30.419931  41.579375   33.793108  54.808984
# 3  994ZZm2aX-E  45.244774  23.591406  23.828802   30.888328  49.698068
# 4  GkDEInsCcpQ  29.958542  29.702031  36.463542   32.041372  55.126803
#
#   thumbnail_text  text_word_count  text_sentiment
# 0                               0             0.0
# 1                               0             0.0
# 2                               0             0.0
# 3                               0             0.0
# 4                               0             0.0

# %%
combined_df.to_csv("video_details_v3.csv", index=False)
